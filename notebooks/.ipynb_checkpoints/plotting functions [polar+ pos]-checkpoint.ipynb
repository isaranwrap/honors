# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import os

from rnn_utils import *

ja = h5py.File('/home/ishan/honors_thesis/joint_angles/ja_101012_134451.h5')['joint_angles']
pos = h5py.File('/home/ishan/princeton_data/preds/101012_134451.h5')['positions_pred']
pos = pos[1000:] #so ja & pos match up
ja_means = ja[:].mean(axis=0)
posFolder = '/home/ishan/princeton_data/preds/'
pos_matrix = np.empty((30,360000,2,32))
for indx, file in enumerate(os.listdir(posFolder)):
    print(file)
    pos = h5py.File(os.path.join(posFolder, file))['positions_pred']
    pos = pos[1000:]
    pos_matrix[indx,:pos.shape[0]] = pos
mean_pos = pos_matrix.mean(axis=1)
# Out:
# 073012_142509.h5
# 100312_111825.h5
# 100512_154639.h5
# 100312_142911.h5
# 073112_133821.h5
# 072612_155218.h5
# 091412_125453.h5
# 072612_144516.h5
# 072712_160725.h5
# 100312_132216.h5
# 073012_120347.h5
# 091412_114909.h5
# 100912_150055.h5
# 072212_163153.h5
# 073012_152817.h5
# 073012_131740.h5
# 101012_134451.h5
# 080312_151623.h5
# 080312_130438.h5
# 080212_152637.h5
# 091712_153058.h5
# 080112_140108.h5
# 091712_141601.h5
# 091212_143038.h5
# 100812_134137.h5
# 092812_134918.h5
# 091712_164027.h5
# 100412_123450.h5
# 100412_112428.h5
# 072512_165305.h5

# %%
for mean_fly in mean_pos:
    draw_skeleton(mean_fly)
# Out:
# /home/ishan/honors_thesis/rnn_utils.py:210: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10,8))

# %%
jaFolder = '/home/ishan/honors_thesis/joint_angles/'
mean_ja = np.empty((30,30))
for indx, file in enumerate(os.listdir(jaFolder)):
    print(file)
    ja = h5py.File(os.path.join(jaFolder, file))['joint_angles']
    mean_ja[indx,...] = ja[:].mean(axis=0)
    
for mean_fly in mean_ja:
    draw_skeleton(mean_fly, input_type='ang')
# Out:
# ja_101012_134451.h5
# ja_073012_152817.h5
# ja_072612_144516.h5
# ja_073012_131740.h5
# ja_080112_140108.h5
# ja_100912_150055.h5
# ja_072212_163153.h5
# ja_080212_152637.h5
# ja_073012_142509.h5
# ja_100312_111825.h5
# ja_100412_112428.h5
# ja_091412_114909.h5
# ja_080312_130438.h5
# ja_100312_142911.h5
# ja_091712_153058.h5
# ja_091412_125453.h5
# ja_072612_155218.h5
# ja_073112_133821.h5
# ja_072512_165305.h5
# ja_091712_141601.h5
# ja_080312_151623.h5
# ja_100312_132216.h5
# ja_073012_120347.h5
# ja_091212_143038.h5
# ja_092812_134918.h5
# ja_100812_134137.h5
# ja_100512_154639.h5
# ja_091712_164027.h5
# ja_072712_160725.h5
# ja_100412_123450.h5

# %%
for mean_flies in zip(mean_pos[:1], mean_ja[:1]):
    draw_skeleton(mean_flies[0])
    draw_skeleton(mean_flies[1], input_type='ang')
